# %%
import geopandas as gp
import pandas as pd
import os
import json
import pylab as pl
import statsmodels.api as sm
import urllib2

s = json.load( open(os.getenv('PUI2015')+'/fbb_matplotlibrc.json') )
pl.rcParams.update(s)
# %pylab inline

# pl.rcParams['font.size'] = 20
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/soheil/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:855: UserWarning: svg.embed_char_paths is deprecated and replaced with svg.fonttype; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
mta = np.load('MTA_Fare.npy')

# %%
mta.shape
# Out:
# (600, 23, 194)

# %%
mta = mta.astype('float')
mta[mta == -1] = np.nan

# %%
rng = pd.date_range('05/21/2010', periods=194, freq='W')
rng
# Out:
# DatetimeIndex(['2010-05-23', '2010-05-30', '2010-06-06', '2010-06-13',
#                '2010-06-20', '2010-06-27', '2010-07-04', '2010-07-11',
#                '2010-07-18', '2010-07-25',
#                ...
#                '2013-12-01', '2013-12-08', '2013-12-15', '2013-12-22',
#                '2013-12-29', '2014-01-05', '2014-01-12', '2014-01-19',
#                '2014-01-26', '2014-02-02'],
#               dtype='datetime64[ns]', length=194, freq='W-SUN', tz=None)

# %%
ridetype = np.array(['10t', '14d', '1d', '2t', '30d', '7d', 'ada', 'afas', 'exp','ez',
            'ff','mc','mr','month','rfm','rr','sen','spec','tcmc','t',
            'umlim','xbus','stud'])

# %%
stations_meanofeachtype = {}
for i in range(mta.shape[0]):
    for j in range(mta.shape[2]):
        stations_meanofeachtype[i, j] = np.mean(mta[i,:, j])

# %%
stations = {}
for i in range(600):
    stations[i] = pd.DataFrame(mta[i, :, :])
    stations[i].columns = rng
    stations[i].set_index(ridetype)
    stations[i] = stations[i].transpose()

# %%
station[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-0696dcd4a106> in <module>()
# ----> 1 station[0]
#
# NameError: name 'station' is not defined

# %%
stations_meanofeachtype
# Out:
# {(570, 129): nan,
#  (185, 101): 2738.913043478261,
#  (5, 178): 1147.9565217391305,
#  (171, 86): 2668.4347826086955,
#  (542, 107): 1465.7826086956522,
#  (104, 115): 6005.869565217391,
#  (157, 23): nan,
#  (450, 3): nan,
#  (512, 10): nan,
#  (90, 42): nan,
#  (143, 36): nan,
#  (436, 82): 1005.4782608695652,
#  (369, 81): 816.82608695652175,
#  (242, 161): 2225.0434782608695,
#  (392, 152): 1137.0869565217392,
#  (265, 110): 1732.1739130434783,
#  (214, 91): 2417.608695652174,
#  (569, 56): nan,
#  (184, 26): nan,
#  (555, 125): nan,
#  (170, 21): nan,
#  (479, 45): nan,
#  (541, 34): nan,
#  (119, 90): 1444.391304347826,
#  (156, 192): 1973.9565217391305,
#  (449, 74): 818.21739130434787,
#  (15, 143): 1928.391304347826,
#  (294, 114): 869.82608695652175,
#  (227, 45): nan,
#  (264, 33): nan,
#  (598, 44): nan,
#  (213, 2): nan,
#  (568, 111): nan,
#  (199, 51): nan,
#  (492, 63): nan,
#  (554, 78): nan,
#  (478, 126): nan,
#  (118, 129): 2662.217391304348,
# ...

# %%
stations_meanofeachtype = {}
for i in range(600):
    for j in range(stations[i].shape[0]):
        stations_meanofeachtype[i] = np.mean(stations[i][j,:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-c9f6ee080442> in <module>()
#       2 for i in range(600):
#       3     for j in range(stations[i].shape[0]):
# ----> 4         stations_meanofeachtype[i] = np.mean(stations[i][j,:])
#
# /home/soheil/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /home/soheil/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# ...

# %% [markdown]
# ax = stations[1].plot()

# %%
pl.figure(figsize = (7, 7))
pl.plot(rng, mta_test)
pl.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-3e29854f6344> in <module>()
#       1 pl.figure(figsize = (7, 7))
# ----> 2 pl.plot(rng, mta_test)
#       3 pl.legend()
#
# /home/soheil/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3097         ax.hold(hold)
#    3098     try:
# -> 3099         ret = ax.plot(*args, **kwargs)
#    3100         draw_if_interactive()
#    3101     finally:
#
# /home/soheil/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1371         lines = []
#    1372
# -> 1373         for line in self._get_lines(*args, **kwargs):
#    1374             self.add_line(line)
#    1375             lines.append(line)
#
# /home/soheil/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
# ...

# %%
pl.figure()
# for i in range(mta.shape[0]):
pl.plot(mta[1, :, :])
pl.legend()
# Out:
# /home/soheil/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
pl.figure()
pl.hist(station1[1], normed=1, histtype='bar', rwidth=0.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-55b6af80bca9> in <module>()
#       1 pl.figure()
# ----> 2 pl.hist(station1[1], normed=1, histtype='bar', rwidth=0.8)
#
# /home/soheil/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2894                       histtype=histtype, align=align, orientation=orientation,
#    2895                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2896                       stacked=stacked, **kwargs)
#    2897         draw_if_interactive()
#    2898     finally:
#
# ...
